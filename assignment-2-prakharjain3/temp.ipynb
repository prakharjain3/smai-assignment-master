# %%
import numpy as np
# to compute angles
from math import atan2, cos, sin, sqrt, pi
# from google.colab.patches import cv2_imshow
import cv2
import matplotlib.pyplot as plt

# %%
# load image
src = cv2.imread('KIMIA dataset/f15.png')
plt.imshow(cv2.cvtColor(src, cv2.COLOR_BGR2RGB))
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/prakhar/Desktop/assignment-2-prakharjain3/temp.ipynb Cell 3 line 1
# ----> <a href='vscode-notebook-cell:/home/prakhar/Desktop/assignment-2-prakharjain3/temp.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> gray = cv2.cvtColor(src, cv2.COLOR_BGR2GRAY)
#       <a href='vscode-notebook-cell:/home/prakhar/Desktop/assignment-2-prakharjain3/temp.ipynb#W2sZmlsZQ%3D%3D?line=1'>2</a> # convert img into binary
#       <a href='vscode-notebook-cell:/home/prakhar/Desktop/assignment-2-prakharjain3/temp.ipynb#W2sZmlsZQ%3D%3D?line=2'>3</a> _, bw = cv2.threshold(gray, 50, 255, cv2.THRESH_BINARY | cv2.THRESH_OTSU)
#
# NameError: name 'src' is not defined
